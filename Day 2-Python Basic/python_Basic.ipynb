# %% [markdown]
# Notebook Title

# %% [markdown]
# # AI/ML Internship - Day 2
#
# ## Name
# Suman Kumar
#
# ## Internship
# AI & Machine Learning Internship
#
# ## Day 2 Task
# Python Basics

# %% [markdown]
# ## Objective
#
# To understand the basics of Python programming including variables, data types,
# operators, loops, functions, and simple programs.

# %% [markdown]
# 1 Variables

# %%
name = "Suman Kumar"
age = 20
course = "AI & ML"

print(name)
print(age)
print(course)
# Out:
# Suman Kumar
# 20
# AI & ML

# %% [markdown]
# 2 Data Types

# %%
a = 10
b = 12.5
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# 3 Arithmetic Operators

# %%
a = 20
b = 38
print(a+b)
# Out:
# 58

# %%
print(a-b)
# Out:
# -18

# %%
print(a*b)
# Out:
# 760

# %%
print(a/b)
# Out:
# 0.5263157894736842

# %%
print(a%b)
# Out:
# 20

# %%
print("Addition :", a+b)
print("Subtraction :", a-b)
print("Multiplication :", a*b)
print("Division :", a/b)
print("Modulus :", a%b)
# Out:
# Addition : 58
# Subtraction : -18
# Multiplication : 760
# Division : 0.5263157894736842
# Modulus : 20

# %% [markdown]
# 4 Comparison Operators

# %%
x = 10
y = 20
print(x==y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
print(x<y)
# Out:
# True

# %%
print(x>y)
# Out:
# False

# %%
x = 15
y = 10

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# 5 User Input

# %%
name = input("Enter your name: ")

print("Welcome", name)
# Out:
# Enter your name:  Suman
# Welcome Suman

# %% [markdown]
# 6 If-Else Program

# %%
number = 12

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Even Number

# %% [markdown]
# 7 For Loop

# %%
for i in range(1,6):
    print("Iteration", i)
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5

# %% [markdown]
# 8 While Loop

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 9 Function

# %%
def square(num):
    return num * num

print(square(8))
# Out:
# 64

# %% [markdown]
# python version

# %%
import sys

print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Conclusion
#
# Successfully completed Day 2 of AI & ML Internship.
#
# Topics Covered
#
# ✔ Variables
#
# ✔ Data Types
#
# ✔ Operators
#
# ✔ If Else
#
# ✔ Loops
#
# ✔ Functions
#
# ✔ Simple Python Programs
